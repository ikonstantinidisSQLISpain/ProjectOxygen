-- %%
%sql
SELECT * FROM oxygen_dev_ikonstantinidis.bronze.whoz_profiles where profile_id = '682e94ac615e062218f44164';

-- %%
%sql
SELECT * FROM oxygen_dev_ikonstantinidis.bronze.whoz_profiles_payload_shapes;

-- %%
%sql
SELECT * FROM oxygen_dev_ikonstantinidis.silver.whoz_profiles  where seeking_opportunities is not null;

-- %%
%sql
SELECT * FROM oxygen_dev_ikonstantinidis.silver.whoz_profile_skill_ratings where rating <> 0;

-- %%
SELECT * FROM oxygen_dev_ikonstantinidis.silver.whoz_profile_aptitudes where profile_id = '682e94ac615e062218f44164';

-- %%
%sql
SELECT * FROM oxygen_dev_ikonstantinidis.silver.whoz_position_aptitude_refs where profile_id = '682e94ac615e062218f44164';

-- %%
SELECT * FROM oxygen_dev_ikonstantinidis.silver.whoz_profile_positions where profile_id = '698e0e776c527124fb8e1611'

-- %%
SELECT * FROM oxygen_dev_ikonstantinidis.silver.whoz_profile_completion_rules;
